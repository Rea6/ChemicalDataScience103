# %% [markdown]
# # Lecture 2: Computational Thinking with Python

# %% [markdown]
# ## Key Concept Review

# %% [markdown]
# ### String operations
#
# Before we begin the exercises, let's review some essential string operations you'll need:
#
# #### Looping Over Strings
# You can loop through each character in a string using a for loop:

# %%
formula = "H2O"
for character in formula:
    print(character)
# Out:
# H
# 2
# O

# %% [markdown]
# #### Useful String Methods
#
# ```python
# string.isalpha() - returns True if the character is a letter
# string.isdigit() - returns True if the character is a number
# string.upper() - converts to uppercase
# string.lower() - converts to lowercase
# ```
#
# Get familiar with these functions by experimenting with them. E.g. what is the output of the following?
# ```python
# "H".isalpha()
# ```

# %%
"1".isdigit()
# Out:
# True

# %% [markdown]
# ### String Indexing and Slicing
# ```python
# formula = "CH4"
# print(formula[0])    # Output: "C" (first character)
# print(formula[1:3])  # Output: "H4" (characters from index 1 to 2)
# print(len(formula))  # Output: 3 (length of string)
# ```
# Familiarise yourself with these functions.

# %%
formula = "Hello"
print(formula[1])
print(formula[-2])
print(formula[1:6])
# Out:
# e
# l
# ello

# %% [markdown]
# ### Converting Strings to Numbers
# ```python
# number_string = "42"
# number = int(number_string)  # Converts "42" to integer 42
# ```
#
# Familiarise yourself with these functions.

# %% [markdown]
# ## Exercise 1: Molecular Formula Parser
#
# **Objective:** Write a function `parse_molecular_formula(formula)` that counts atoms in molecular formulas. Start with the simple cases, but design your solution to handle increasingly complex inputs without major rewrites.
#
# **Think computationally:** How can you break this problem into smaller, reusable pieces that won't need to be completely rewritten when the requirements change?

# %%
from typing import Dict

def parse_molecular_formula(formula: str) -> Dict[str, int]:
    atom_dict = dict()
    i=-1 #marks the position 
    for character in formula: #loops through the formula
        i=+1 
        if formula[i].isdigit() == True: #in case it is a number or like second letter of Na skip !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
             continue
        if character.islower() == True:
             continue

        
        if character.isalpha == True:                                                #when character is a Letter
            if formula[i+1].isdigit() == True or formula[i+2].isdigit() == True:    #if the next or second next letter is a number:¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨
                if formula[i+1].islower() == True:                                 # if the next letter is small
                    if formula[i, i+1] in atom_dict.keys(): #if the Atom is already in the dict
                        atom_dict[formula[i:i+2]] += 1
                        continue
                    
                        #atom_dict[formula[i:i+2]] = 1 #else: make a new entry
                        #continue
                #else

            else:
                atom_dict[formula[i]] = 1 #else: make a new entry
                continue
            

            if character in atom_dict.keys() == True and formula[i+1].isupper == True: #if it is in the dict and not 2 letters
                atom_dict[character] +=1 #add one to the number
                continue
            


    # Write your code here
    #Number
    
    return atom_dict

# %%
#https://regex101.com/

# %%
from typing import Dict

def parse_molecular_formula(formula: str) -> Dict[str, int]:
    atom_dict = dict()

    for i in range(len(formula)):

        # Check if it is a element bc they start with a big letter, otherwise: nothing
        if formula[i].isupper() == True:

            element = formula[i]

            # Check if it is a two-letter element, (and stop before formula is done to not get an error)
            if i + 1 < len(formula) and formula[i + 1].islower() ==True:
                element = formula[i:i + 2]

                # Check for a number after the two-letter element, (and stop before formula is done to not get an error)
                if i + 2 < len(formula) and formula[i + 2].isdigit() == True:

                    number = formula[i + 2]

                    # Check for a number after the number, (and stop before formula is done to not get an error)
                    if i + 3 < len(formula) and formula[i + 3].isdigit() == True:
                        number += formula[i + 3]

                    count = int(number) # turn the count into an integer to perform math. activities with it

                else:
                    count = 1

            # If no small letter is found
            else:

                # Check for a number after the element (and stop before formula is done to not get an error)
                if i + 1 < len(formula) and formula[i + 1].isdigit() == True:

                    number = formula[i + 1]

                    # Check for a second digit (and stop before formula is done to not get an error)
                    if i + 2 < len(formula) and formula[i + 2].isdigit() == True:
                        number += formula[i + 2]

                    count = int(number)

                else:
                    count = 1

            # Add element to dictionary
            if element in atom_dict:
                atom_dict[element] += count
            else:
                atom_dict[element] = count
        else:
            continue

    return atom_dict

# %%
l = "hello"
print(l[1])
# Out:
# e

# %% [markdown]
# ### Test cases: Set 1 Basic formulae

# %% [markdown]
# The test cases will increase in difficulty with each set. Start with the first set, but think about how your approach will scale to the later, more complex cases.

# %%
# Simple single-letter elements, single-digit counts
test_cases_level1 = [
    ("H2O", {"H": 2, "O": 1}),
    ("CH", {"C": 1, "H": 1}),
    ("CO2", {"C": 1, "O": 2}),
    ("NH3", {"N": 1, "H": 3})
]

for formula, expected in test_cases_level1:
    result = parse_molecular_formula(formula)
    print(f"{formula}: {result} {'✓' if result == expected else '✗'}")
# Out:
# H2O: {'H': 2, 'O': 1} ✓
# CH: {'C': 1, 'H': 1} ✓
# CO2: {'C': 1, 'O': 2} ✓
# NH3: {'N': 1, 'H': 3} ✓

# %% [markdown]
# ### Test cases: Set 2 Multi-letter Elements

# %%
# Two-letter elements like Ca, Cl, Na
test_cases_level2 = [
    ("NaCl", {"Na": 1, "Cl": 1}),
    ("CaCl2", {"Ca": 1, "Cl": 2}),
    ("MgO", {"Mg": 1, "O": 1}),
    ("AlCl3", {"Al": 1, "Cl": 3}),
    ("H2SO4", {"H": 2, "S": 1, "O": 4})
]

for formula, expected in test_cases_level2:
    result = parse_molecular_formula(formula)
    print(f"{formula}: {result} {'✓' if result == expected else '✗'}")
# Out:
# NaCl: {'Na': 1, 'Cl': 1} ✓
# CaCl2: {'Ca': 1, 'Cl': 2} ✓
# MgO: {'Mg': 1, 'O': 1} ✓
# AlCl3: {'Al': 1, 'Cl': 3} ✓
# H2SO4: {'H': 2, 'S': 1, 'O': 4} ✓

# %% [markdown]
# ### Test cases: Set 3 Large Numbers

# %%
# Multi-digit counts
test_cases_level3 = [
    ("C12H22O11", {"C": 12, "H": 22, "O": 11}),  # Sucrose
    ("Ca10P6O26", {"Ca": 10, "P": 6, "O": 26}),   # Hydroxyapatite
    ("C2H5OH", {"C": 2, "H": 6, "O": 1}),         # Ethanol
    ("Fe2O3", {"Fe": 2, "O": 3})                  # Iron oxide
]

for formula, expected in test_cases_level3:
    result = parse_molecular_formula(formula)
    print(f"{formula}: {result} {'✓' if result == expected else '✗'}")
# Out:
# C12H22O11: {'C': 12, 'H': 22, 'O': 11} ✓
# Ca10P6O26: {'Ca': 10, 'P': 6, 'O': 26} ✓
# C2H5OH: {'C': 2, 'H': 6, 'O': 1} ✓
# Fe2O3: {'Fe': 2, 'O': 3} ✓
